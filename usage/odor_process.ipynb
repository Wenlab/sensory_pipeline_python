# %% [markdown]
# ## Config

# %%
import sys
sys.path.append("..")

# %% [markdown]
# ## Load worm data from infer result and ID annotation
# - get stimulus interval info from output_volumes.xlsx
# - get ID data from ID.xlsx
# - get intensity data from HDF5 file
# - detrend and save data in a dictionary

# %%
from data_load.process_worm_data import load_and_process_worm_data

# sorting_config_0604 = {
#     'w3':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w4':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w6':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w7':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w10':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     }
# }

experiment_df_0604_odor, stimulus_lists_0604_odor, ID_info_0604_odor, worm_data_0604_odor, neuron_segments_dict_0604_odor, neuron_segments_dict_reorganized_0604_odor, neuron_groups_0604_odor = load_and_process_worm_data(
    # h5_file_path=  r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\20250604.h5",
    h5_file_path=  r"G:\LAB\DATA\Olfactory\result\20250604\20250604.h5",
    # channel_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\output_volumes.xlsx",
    channel_info_path= r"G:\LAB\DATA\Olfactory\result\20250604\output_volumes.xlsx",
    # ID_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\ID0604_odor.xlsx",
    ID_info_path= r"G:\LAB\DATA\Olfactory\result\20250604\ID0604_odor.xlsx",
    date='20250604',
    sorting_config=None,
)

# %%
# sorting_config_0529 = {
#     'w3':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w4':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w6':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w7':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w10':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     }
# }

experiment_df_0529_odor, stimulus_lists_0529_odor, ID_info_0529_odor, worm_data_0529_odor, neuron_segments_dict_0529_odor, neuron_segments_dict_reorganized_0529_odor, neuron_groups_0529_odor = load_and_process_worm_data(
        h5_file_path=  r"G:\LAB\DATA\Olfactory\result\20250529\20250529.h5",
        channel_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\output_volumes.xlsx",
        ID_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\ID0529_odor.xlsx",
        date='20250529',
        sorting_config=None)

# %%
from data_load.process_worm_data import merge_multiple_dicts
all_neuron_segments = merge_multiple_dicts(neuron_segments_dict_reorganized_0604_odor, neuron_segments_dict_reorganized_0529_odor)

# %%
import copy
neuron_segments_dict = copy.deepcopy(all_neuron_segments)
neuron_groups = copy.deepcopy(neuron_groups_0604_odor)

# %%
neuron_segments_dict.keys()
# Out:
# dict_keys(['ADFL', 'ADFR', 'ADLL', 'ADLR', 'AFDR', 'ASER', 'ASGL', 'ASGR', 'ASHL', 'ASHR', 'ASIL', 'ASIR', 'ASJL', 'ASJR', 'ASKL', 'ASKR', 'AWAL', 'AWAR', 'AWBL', 'AWBR', 'AWCL', 'AWCR'])

# %%
# select distinct keys
keys_to_copy = ['ASHL', 'AWBL', 'ASKL', 'ASJL', 'ASJR', 'ASHR', 'ASKR', 'ADFR', 'AWAL', 'ASEL', 'ADFL', 'AWAR', 'AWBR', 'ASER']
neuron_segments_dict = {key: copy.deepcopy(neuron_segments_dict[key]) for key in keys_to_copy}
neuron_groups = {key: copy.deepcopy(neuron_groups[key]) for key in keys_to_copy}

# %% [markdown]
# ## plot

# %%
import json
# with open(r'H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\odor_info.json', 'r') as f:
with open(r'G:\LAB\CODE\sensory_pipeline\data_load\config\odor_info.json', 'r') as f:
# with open(r'G:\LAB\CODE\sensory_pipeline\data_load\config\compound_info.json', 'r') as f:
    compounds = json.load(f)

# %%
from result_plot.draw_signal_with_ID import plot_neurons_to_pdf
output_pdf = r'G:\LAB\DATA\Olfactory\result\20250529\neuron_segments.pdf'
plot_neurons_to_pdf(neuron_segments_dict, compounds,output_pdf, if_combine=False)
# Out:
# PDF saved to G:\LAB\DATA\Olfactory\result\20250529\neuron_segments.pdf
# 'G:\\LAB\\DATA\\Olfactory\\result\\20250529\\neuron_segments.pdf'

# %%
from result_plot.radar_heatmap_plot import compare_compounds_and_dilutions, heatmap_plot
import os
# output_folder = r"H:\Process_temporary\WJH\olfactory\ID\result\20250428_The\visulization_0513_1"
output_folder = r"G:\LAB\DATA\Olfactory\result\20250529\plot_with_0604\Radar"
os.makedirs(output_folder, exist_ok=True)
compare_compounds_and_dilutions(neuron_segments_dict, compounds, output_folder, interactive=True,if_combine=False, if_sum_normalization=True)
# Out:
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Benzaldehyde Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Benzaldehyde Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Linalool Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Linalool Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Trans-beta-ionone Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Trans-beta-ionone Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Geraniol Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Geraniol Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Benzaldehyde Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Linalool Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Trans-beta-ionone Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Geraniol Dilutions
# (<Figure size 1200x1000 with 1 Axes>,
#  {'c4': <Figure size 1200x1000 with 1 Axes>,
#   'c5': <Figure size 1200x1000 with 1 Axes>,
#   'c6': <Figure size 1200x1000 with 1 Axes>,
#   'c7': <Figure size 1200x1000 with 1 Axes>},
#  {'compounds': Figure({
#       'data': [{'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Benzaldehyde',
#                 'opacity': 0.7,
#                 'r': [0.16682922840118408, 0.056940458714962006,
#                       0.35070088505744934, 0.042816244065761566, 0.07079649716615677,
#                       0.34310492873191833, 0.11796288192272186, 0.1001114472746849,
#                       1.3526792526245117, 0.3527740240097046, 0.526602029800415,
#                       0.1741267442703247, 0.21259839832782745, 0.0953238382935524,
#                       0.03728852793574333, 0.08477553725242615,
#                       0.0014734166907146573, 0.015506637282669544,
#                       0.07682428508996964, 0.0028511211276054382,
#                       0.23552557826042175, 0.08791213482618332, 0.16682922840118408],
#                 'theta': [AWCL, AFDR, ASKR, ASJL, AWAR, ASKL, ADLR, AWAL, AWBR,
#                           AWBL, ASHR, ADFR, ASER, ASJR, ASIL, AWCR, ASIR, ASGR, ADLL,
#                           ASGL, ASHL, ADFL, AWCL],
#                 'type': 'scatterpolar'},
#                {'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Linalool',
#                 'opacity': 0.7,
#                 'r': [0.0937330573797226, 0.05578066408634186, 0.5039801001548767,
#                       0.1140119880437851, 0.17362253367900848, 0.37691184878349304,
#                       0.1420871615409851, 0.09282766282558441, 0.04639801010489464,
#                       0.13828019797801971, 0.17557060718536377, 0.06124158203601837,
#                       0.2051471620798111, 0.44366490840911865, 0.15349692106246948,
#                       0.20251356065273285, 0.05184372887015343, 0.13200241327285767,
#                       0.34091654419898987, 0.02230573445558548, 0.19353410601615906,
#                       0.05207468196749687, 0.0937330573797226],
#                 'theta': [AWCL, AFDR, ASKR, ASJL, AWAR, ASKL, ADLR, AWAL, AWBR,
#                           AWBL, ASHR, ADFR, ASER, ASJR, ASIL, AWCR, ASIR, ASGR, ADLL,
#                           ASGL, ASHL, ADFL, AWCL],
#                 'type': 'scatterpolar'},
#                {'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Trans-beta-ionone',
#                 'opacity': 0.7,
#                 'r': [0.18166032433509827, 0.0562698058784008, 0.41532382369041443,
#                       0.09630690515041351, 0.025396917015314102, 0.2674162685871124,
#                       0.06983405351638794, 0.03315021097660065, 0.24606375396251678,
#                       0.15641538798809052, 0.14793914556503296, 0.020275473594665527,
#                       0.18111571669578552, 0.8980450630187988, 0.22285492718219757,
#                       0.2424098402261734, 0.06460952758789062, 0.07055097818374634,
#                       0.04164651408791542, 0.012987077236175537, 0.21450218558311462,
#                       0.07452239841222763, 0.18166032433509827],
#                 'theta': [AWCL, AFDR, ASKR, ASJL, AWAR, ASKL, ADLR, AWAL, AWBR,
#                           AWBL, ASHR, ADFR, ASER, ASJR, ASIL, AWCR, ASIR, ASGR, ADLL,
#                           ASGL, ASHL, ADFL, AWCL],
#                 'type': 'scatterpolar'},
#                {'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Geraniol',
#                 'opacity': 0.7,
#                 'r': [0.04966270551085472, 0.04892123490571976, 0.171880304813385,
#                       0.004266656935214996, 0.04392341896891594, 0.26287728548049927,
#                       0.04145579785108566, 0.01765812188386917, 0.4379498362541199,
#                       0.26759862899780273, 0.4192507266998291, 0.19119274616241455,
#                       0.21426786482334137, 0.8255549669265747, 0.23883414268493652,
#                       0.3619798421859741, 0.1318538784980774, 0.184253990650177,
#                       0.4443883001804352, 0.14179112017154694, 0.5657612681388855,
#                       0.11101417988538742, 0.04966270551085472],
#                 'theta': [AWCL, AFDR, ASKR, ASJL, AWAR, ASKL, ADLR, AWAL, AWBR,
#                           AWBL, ASHR, ADFR, ASER, ASJR, ASIL, AWCR, ASIR, ASGR, ADLL,
#                           ASGL, ASHL, ADFL, AWCL],
#                 'type': 'scatterpolar'}],
#       'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                   'showarrow': False,
#                                   'text': 'Values represent peak response during stimulus period',
#                                   'x': 0.5,
#                                   'xref': 'paper',
#                                   'y': -0.15,
#                                   'yref': 'paper'}],
#                  'height': 800,
#                  'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                  'polar': {'radialaxis': {'range': [0, 1.4879472255706787], 'visible': True}},
#                  'showlegend': True,
#                  'template': '...',
#                  'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Different Compounds', 'x': 0.5},
#                  'width': 800}
#   }),
#   'dilutions': {'Benzaldehyde': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.08791213482618332, 0.1741267442703247, 0.07682428508996964,
#                        0.11796288192272186, 0.056940458714962006, 0.21259839832782745,
#                        0.0028511211276054382, 0.015506637282669544,
#                        0.23552557826042175, 0.526602029800415, 0.03728852793574333,
#                        0.0014734166907146573, 0.042816244065761566,
#                        0.0953238382935524, 0.34310492873191833, 0.35070088505744934,
#                        0.1001114472746849, 0.07079649716615677, 0.3527740240097046,
#                        1.3526792526245117, 0.16682922840118408, 0.08477553725242615,
#                        0.08791213482618332],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 1.4879472255706787], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Benzaldehyde Dilutions', 'x': 0.5},
#                   'width': 800}
#    }),
#    'Linalool': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.05207468196749687, 0.06124158203601837, 0.34091654419898987,
#                        0.1420871615409851, 0.05578066408634186, 0.2051471620798111,
#                        0.02230573445558548, 0.13200241327285767, 0.19353410601615906,
#                        0.17557060718536377, 0.15349692106246948, 0.05184372887015343,
#                        0.1140119880437851, 0.44366490840911865, 0.37691184878349304,
#                        0.5039801001548767, 0.09282766282558441, 0.17362253367900848,
#                        0.13828019797801971, 0.04639801010489464, 0.0937330573797226,
#                        0.20251356065273285, 0.05207468196749687],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 0.5543781518936157], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Linalool Dilutions', 'x': 0.5},
#                   'width': 800}
#    }),
#    'Trans-beta-ionone': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.07452239841222763, 0.020275473594665527,
#                        0.04164651408791542, 0.06983405351638794, 0.0562698058784008,
#                        0.18111571669578552, 0.012987077236175537, 0.07055097818374634,
#                        0.21450218558311462, 0.14793914556503296, 0.22285492718219757,
#                        0.06460952758789062, 0.09630690515041351, 0.8980450630187988,
#                        0.2674162685871124, 0.41532382369041443, 0.03315021097660065,
#                        0.025396917015314102, 0.15641538798809052, 0.24606375396251678,
#                        0.18166032433509827, 0.2424098402261734, 0.07452239841222763],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 0.9878495931625366], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Trans-beta-ionone Dilutions', 'x': 0.5},
#                   'width': 800}
#    }),
#    'Geraniol': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.11101417988538742, 0.19119274616241455, 0.4443883001804352,
#                        0.04145579785108566, 0.04892123490571976, 0.21426786482334137,
#                        0.14179112017154694, 0.184253990650177, 0.5657612681388855,
#                        0.4192507266998291, 0.23883414268493652, 0.1318538784980774,
#                        0.004266656935214996, 0.8255549669265747, 0.26287728548049927,
#                        0.171880304813385, 0.01765812188386917, 0.04392341896891594,
#                        0.26759862899780273, 0.4379498362541199, 0.04966270551085472,
#                        0.3619798421859741, 0.11101417988538742],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 0.908110499382019], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Geraniol Dilutions', 'x': 0.5},
#                   'width': 800}
#    })}})

# %%
output_folder = r"G:\LAB\DATA\Olfactory\result\20250529\plot_with_0604\Heatmap"
heatmap_plot(neuron_segments_dict, compounds, output_folder, if_combine=False)

# %%
from result_analysis.react_time import calculate_time_to_segment_half_peak
time_to_half_peak_results = calculate_time_to_segment_half_peak(neuron_segments_dict)

# %%
from utils.HDF5Toolkit import save_h5file
# save_h5file(r"G:\LAB\CODE\sensory_pipeline\data\neuron_segments.h5", "neuron_segments_dict", mode='w', **neuron_segments_dict)
save_h5file(r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\neuron_segments_dict.h5", "neuron_segments_dict", mode='w', **neuron_segments_dict)

# %%
from utils.HDF5_load import load_h5file
neuron_segments_dict = load_h5file(
    # r"G:\LAB\CODE\sensory_pipeline\data\neuron_segments.h5", 
    r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\neuron_segments_dict.h5",   
    # r"H:\Process_temporary\WJH\olfactory\analysis\coffee_neuron_segments.h5",   
    "neuron_segments_dict"
)

# %%
from result_plot.visweb import create_neuronal_dashboard
app = create_neuronal_dashboard(neuron_segments_dict, compounds)  # Change port if needed
app.run(port=8050, debug=True, jupyter_mode='external')
# Out:
# Dash app running on http://127.0.0.1:8050/
