# %% [markdown]
# ## Config

# %%
import sys
sys.path.append("..")

# %% [markdown]
# ## Load worm data from infer result and ID annotation
# - get stimulus interval info from output_volumes.xlsx
# - get ID data from ID.xlsx
# - get intensity data from HDF5 file
# - detrend and save data in a dictionary

# %%
stimulus_lists_0529_odor
# Out:
# {'w2': ['c4_1', 'c4_1', 'c5_1', 'c5_1', 'c6_1', 'c6_1', 'c7_1', 'c7_1'],
#  'w3': ['c7_1', 'c7_1', 'c6_1', 'c6_1', 'c5_1', 'c5_1', 'c4_1'],
#  'w4': ['c7_1', 'c7_1', 'c6_1', 'c6_1', 'c5_1', 'c5_1', 'c4_1', 'c4_1']}

# %%
stimulus_lists_0604_odor
# Out:
# {'w1': ['c4_1', 'c4_1', 'c5_1', 'c5_1', 'c6_1', 'c6_1', 'c7_1', 'c7_1'],
#  'w2': ['c4_1', 'c4_1', 'c5_1', 'c5_1', 'c6_1', 'c6_1', 'c7_1', 'c7_1'],
#  'w3': ['c7_1', 'c7_1', 'c6_1', 'c6_1', 'c5_1', 'c5_1', 'c4_1', 'c4_1'],
#  'w4': ['c7_1', 'c7_1', 'c6_1', 'c6_1', 'c5_1', 'c5_1', 'c4_1', 'c4_1'],
#  'w5': ['c4_1', 'c4_1', 'c5_1', 'c5_1', 'c6_1', 'c6_1', 'c7_1', 'c7_1'],
#  'w6': ['c7_1', 'c7_1', 'c6_1', 'c6_1', 'c5_1', 'c5_1', 'c4_1', 'c4_1'],
#  'w7': ['c7_1', 'c7_1', 'c6_1', 'c6_1', 'c5_1', 'c5_1', 'c4_1', 'c4_1'],
#  'w8': ['c4_1', 'c4_1', 'c5_1', 'c5_1', 'c6_1', 'c6_1', 'c7_1', 'c7_1'],
#  'w9': ['c4_1', 'c4_1', 'c5_1', 'c5_1', 'c6_1', 'c6_1', 'c7_1', 'c7_1'],
#  'w10': ['c7_1', 'c7_1', 'c6_1', 'c6_1', 'c5_1', 'c5_1', 'c4_1', 'c4_1']}

# %%
ID_0604_odor
# Out:
# {'w1':     digital biological Unnamed: 2
#  0         0        NaN       FLPR
#  1         1       ASIR        NaN
#  2         2       ASGR        NaN
#  3         3        NaN        NaN
#  4         4       ASKR        NaN
#  5         5        NaN        NaN
#  6         6       ADFR        NaN
#  7         7       AWBR        NaN
#  8         8       ASER        NaN
#  9         9       ADLR        NaN
#  10       10        NaN        NaN
#  11       11        NaN        NaN
#  12       12       ASHR        NaN
#  13       13       AWAR        NaN
#  14       14        NaN        NaN
#  15       15        NaN        NaN
#  16       16       ASJR        NaN
#  17       17       AWCR        NaN
#  18       18        NaN        NaN
#  19       19        NaN       URXR
#  20       20        NaN        NaN
#  21       21        NaN        NaN
#  22       22        NaN        NaN
#  23       23        NaN        NaN
#  24       24        NaN        NaN
#  25       25        NaN        NaN
#  26       26        NaN        NaN
#  27       27        NaN        NaN
#  28       28       ASKL        NaN
#  29       29       AWCL        NaN
#  30       30        NaN        NaN
#  31       31       ASJL        NaN
#  32       32        NaN        NaN
#  33       33       ASHL        NaN
#  34       34       ADFL        NaN
#  35       35       AWAL        NaN
#  36       36        NaN        NaN
#  37       37       ASGL        NaN
#  38       38       ASIL        NaN
#  39       39        NaN        NaN
#  40       40        NaN        NaN,
#  'w2':     digital biological Unnamed: 2
#  0         0       FLPR        NaN
#  1         1       ASIR        NaN
#  2         2       ASGR        NaN
#  3         3        NaN        NaN
#  4         4       ASER        NaN
#  5         5       ASHR        NaN
#  6         6        NaN        NaN
#  7         7       ASKR        NaN
#  8         8       ADLR        NaN
#  9         9        NaN        NaN
#  10       10       AWBR        NaN
#  11       11       AWAR        NaN
#  12       12       ADFR        NaN
#  13       13        NaN        NaN
#  14       14       AWCR        NaN
#  15       15        NaN        NaN
#  16       16        NaN        NaN
#  17       17       ASJR        NaN
#  18       18        NaN        NaN
#  19       19        NaN        NaN
#  20       20        NaN        NaN
#  21       21        NaN        NaN
#  22       22        NaN        NaN
#  23       23        NaN        NaN
#  24       24        NaN        NaN
#  25       25        NaN        NaN
#  26       26       ASKL        NaN
#  27       27        NaN        NaN
#  28       28       AWCL        NaN
#  29       29       AWAL        NaN
#  30       30        NaN       AWBL
#  31       31       ASJL        NaN
#  32       32       ADFL        NaN
#  33       33        NaN        NaN
#  34       34       ASHL        NaN
#  35       35       ASIL        NaN
#  36       36        NaN       AWBL
#  37       37       AWBL        NaN,
#  'w3':     digital biological Unnamed: 2
#  0         0       ASIR        NaN
#  1         1        NaN       FLPR
#  2         2       ASGR        NaN
#  3         3       ADLR        NaN
#  4         4        NaN        NaN
#  5         5       ASHR        NaN
#  6         6        NaN        NaN
#  7         7       ASER        NaN
#  8         8        NaN        NaN
#  9         9       ASKR        NaN
#  10       10       AWAR        NaN
#  11       11       ADFR        NaN
#  12       12       AWCR        NaN
#  13       13        NaN        NaN
#  14       14        NaN        NaN
#  15       15        NaN        NaN
#  16       16        NaN        NaN
#  17       17       ASJR        NaN
#  18       18        NaN        NaN
#  19       19        NaN        NaN
#  20       20        NaN        NaN
#  21       21        NaN        NaN
#  22       22       ASKL        NaN
#  23       23       ADLL        NaN
#  24       24       ADFL        NaN
#  25       25       AWCL        NaN
#  26       26       ASGL        NaN
#  27       27       AWAL        NaN
#  28       28       ASIL        NaN
#  29       29        NaN        NaN,
#  'w4':     digital biological Unnamed: 2
#  0         0        NaN       FLPR
#  1         1       ASIR        NaN
#  2         2       ASGR        NaN
#  3         3       ASHR        NaN
#  4         4       ASER        NaN
#  5         5       ASER        NaN
#  6         6       ADLR        NaN
#  7         7       ADFR        NaN
#  8         8       ASKR        NaN
#  9         9        NaN        NaN
#  10       10        NaN        NaN
#  11       11       AWAR        NaN
#  12       12       ASHR        NaN
#  13       13       AWCR        NaN
#  14       14       ASJR        NaN
#  15       15        NaN       ADLR
#  16       16        NaN        NaN
#  17       17        NaN        NaN
#  18       18        NaN        NaN
#  19       19        NaN        NaN
#  20       20       ADFL        NaN
#  21       21       ADLL        NaN
#  22       22       AWCL        NaN
#  23       23       ASGL    notsure
#  24       24        NaN        NaN,
#  'w5':     digital biological   Unnamed: 2
#  0         0       AWAR  notsure ASG
#  1         1       ASGR          ASI
#  2         2       ASER          NaN
#  3         3        NaN         FLPR
#  4         4       ADLR          NaN
#  5         5        NaN          NaN
#  6         6       ASHR          NaN
#  7         7       AFDR      notsure
#  8         8       ASKR          NaN
#  9         9        NaN  interesting
#  10       10        NaN          NaN
#  11       11        NaN          NaN
#  12       12        NaN         ASKR
#  13       13        NaN          NaN
#  14       14       ASJR          NaN
#  15       15        NaN          NaN
#  16       16       AWCR          NaN
#  17       17        NaN          NaN
#  18       18        NaN          NaN
#  19       19       ASKL          NaN
#  20       20        NaN          NaN
#  21       21       ASHL          NaN
#  22       22        NaN          NaN
#  23       23        NaN          NaN
#  24       24       ADFL          NaN,
#  'w6':     digital biological          Unnamed: 2
#  0         0       ASGR                ASIR
#  1         1        NaN                FLPR
#  2         2       ADLR                 NaN
#  3         3       AWAR  ASGR very not sure
#  4         4       ASER                 NaN
#  5         5       ASHR                 NaN
#  6         6       AWBR        OFF-response
#  7         7       AFDR                 NaN
#  8         8       ASKR                 NaN
#  9         9        NaN                 NaN
#  10       10        NaN                 NaN
#  11       11       ADFR                 NaN
#  12       12        NaN                 NaN
#  13       13        NaN                 NaN
#  14       14       ASJR                 NaN
#  15       15        NaN                 NaN
#  16       16        NaN                 NaN
#  17       17        NaN                 NaN
#  18       18        NaN                 NaN
#  19       19        NaN                 NaN
#  20       20        NaN                 NaN
#  21       21       ASKL                 NaN
#  22       22        NaN                 NaN
#  23       23       ADLL                 NaN
#  24       24       ASHL                 NaN,
#  'w7':     digital biological Unnamed: 2
#  0         0       ASIR        NaN
#  1         1        NaN       FLPR
#  2         2       ADLR        NaN
#  3         3       ASGR        NaN
#  4         4       ASER        NaN
#  5         5        NaN       AFDR
#  6         6       AWBR        NaN
#  7         7       ASKR        NaN
#  8         8       ASHR        NaN
#  9         9       ADFR        NaN
#  10       10        NaN        NaN
#  11       11        NaN          k
#  12       12       AWCR        NaN
#  13       13        NaN        NaN
#  14       14       ASJR        NaN
#  15       15        NaN        NaN
#  16       16        NaN        NaN
#  17       17       ASKL        NaN
#  18       18       ADLL        NaN
#  19       19       ADFL    notsure
#  20       20       ASHL        NaN
#  21       21        NaN        NaN
#  22       22       AWCL        NaN
#  23       23       ASIL        NaN,
#  'w8':     digital biological        Unnamed: 2
#  0         0       ADLL               NaN
#  1         1       ASKL               NaN
#  2         2       ASIL               NaN
#  3         3        NaN              URXL
#  4         4        NaN               NaN
#  5         5        NaN               NaN
#  6         6        NaN               NaN
#  7         7        NaN              ASIL
#  8         8        NaN               NaN
#  9         9       ADLR               NaN
#  10       10       ASIR               NaN
#  11       11        NaN               NaN
#  12       12       AWCL               NaN
#  13       13        NaN              AFDL
#  14       14        NaN               NaN
#  15       15       ASKR               NaN
#  16       16        NaN               NaN
#  17       17        NaN           notsure
#  18       18       ASHL               NaN
#  19       19        NaN           notsure
#  20       20        NaN               NaN
#  21       21        NaN               NaN
#  22       22       ASHR               NaN
#  23       23        NaN  seem to be wrong
#  24       24        NaN               NaN,
#  'w9':     digital biological Unnamed: 2
#  0         0        NaN       FLPR
#  1         1       ASKR        NaN
#  2         2        NaN        NaN
#  3         3       ASIR      maybe
#  4         4       ADLR        NaN
#  5         5       ADFR  AFDR/ADFR
#  6         6       ASER        NaN
#  7         7       ASHR        NaN
#  8         8       AWCR        NaN
#  9         9        NaN        NaN
#  10       10        NaN        NaN
#  11       11        NaN        NaN
#  12       12       ASHR        NaN
#  13       13        NaN       URXR
#  14       14        NaN        NaN
#  15       15        NaN        NaN
#  16       16        NaN          k
#  17       17        NaN       AWCR
#  18       18       ASJR        NaN
#  19       19        NaN        NaN
#  20       20        NaN        NaN
#  21       21        NaN        NaN
#  22       22        NaN        NaN
#  23       23        NaN        NaN
#  24       24        NaN        NaN
#  25       25        NaN        NaN
#  26       26        NaN        NaN
#  27       27       ASKL        NaN
#  28       28       ASHL        NaN
#  29       29        NaN        NaN
#  30       30        NaN        NaN
#  31       31       AWAL        NaN
#  32       32       ADLL        NaN,
#  'w10':     digital biological Unnamed: 2
#  0         0        NaN       FLPR
#  1         1       ASKR        NaN
#  2         2       ASIR        NaN
#  3         3       ADLR        NaN
#  4         4       ADFR        NaN
#  5         5       AWCR        NaN
#  6         6       AWBR       AWAR
#  7         7       ASER        NaN
#  8         8       ASHR        NaN
#  9         9        NaN       ASHR
#  10       10        NaN       AWCR
#  11       11        NaN        NaN
#  12       12        NaN       URXR
#  13       13        NaN        NaN
#  14       14        NaN        NaN
#  15       15       ASJR        NaN
#  16       16        NaN        NaN
#  17       17        NaN        NaN
#  18       18        NaN        NaN
#  19       19        NaN        NaN
#  20       20       AWCL        NaN
#  21       21       ASHL        NaN
#  22       22       ASKL        NaN
#  23       23        NaN       ASEL}

# %%
from data_load.process_worm_data import load_and_process_worm_data

# sorting_config_0604 = {
#     'w3':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w4':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w6':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w7':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w10':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     }
# }

experiment_df_0604_odor, stimulus_lists_0604_odor, ID_info_0604_odor, worm_data_0604_odor, neuron_segments_dict_0604_odor, neuron_segments_dict_reorganized_0604_odor, neuron_groups_0604_odor = load_and_process_worm_data(
    h5_file_path=  r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\20250604.h5",
    channel_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\output_volumes.xlsx",
    ID_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\ID0604_odor.xlsx",
    date='20250604',
    sorting_config=None,
)

# %%
sorting_config_0529 = {
    'w3':{
            'stimulus_sort': [6,7,4,5,2,3,0,1],
            'buffer_sort': [0,7,8,5,6,3,4,1,2]
    },
    'w4':{
            'stimulus_sort': [6,7,4,5,2,3,0,1],
            'buffer_sort': [0,7,8,5,6,3,4,1,2]
    },
    'w6':{
            'stimulus_sort': [6,7,4,5,2,3,0,1],
            'buffer_sort': [0,7,8,5,6,3,4,1,2]
    },
    'w7':{
            'stimulus_sort': [6,7,4,5,2,3,0,1],
            'buffer_sort': [0,7,8,5,6,3,4,1,2]
    },
    'w10':{
            'stimulus_sort': [6,7,4,5,2,3,0,1],
            'buffer_sort': [0,7,8,5,6,3,4,1,2]
    }
}

# %%
from data_load.process_worm_data import merge_multiple_dicts
all_neuron_segments = merge_multiple_dicts(neuron_segments_dict_reorganized_0604_odor)

# %%
import copy
neuron_segments_dict = copy.deepcopy(all_neuron_segments)
neuron_groups = copy.deepcopy(neuron_groups_0604_odor)

# %%
# select distinct keys
keys_to_copy = ['ASHL', 'AWBL', 'ASKL', 'ASJL', 'ASJR', 'ASHR', 'ASKR', 'ADFR', 'AWAL', 'ASEL', 'ADFL', 'AWAR', 'AWBR', 'ASER']
neuron_segments_dict = {key: copy.deepcopy(neuron_segments_dict[key]) for key in keys_to_copy}
neuron_groups = {key: copy.deepcopy(neuron_groups[key]) for key in keys_to_copy}

# %% [markdown]
# ## plot

# %%
import json
with open(r'H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\odor_info.json', 'r') as f:
# with open(r'H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\coffee_info.json', 'r') as f:
# with open(r'G:\LAB\CODE\sensory_pipeline\data_load\config\compound_info.json', 'r') as f:
    compounds = json.load(f)

# %%
from result_plot.draw_signal_with_ID import plot_neurons_to_pdf
output_pdf = r'H:\Process_temporary\WJH\olfactory\ID\result\20250604\Plot\neuron_segments.pdf'
plot_neurons_to_pdf(neuron_segments_dict, compounds,output_pdf, if_combine=False)
# Out:
# PDF saved to H:\Process_temporary\WJH\olfactory\ID\result\20250604\Plot\neuron_segments.pdf
# 'H:\\Process_temporary\\WJH\\olfactory\\ID\\result\\20250604\\Plot\\neuron_segments.pdf'

# %%
from result_plot.radar_heatmap_plot import compare_compounds_and_dilutions, heatmap_plot
import os
# output_folder = r"H:\Process_temporary\WJH\olfactory\ID\result\20250428_The\visulization_0513_1"
output_folder = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\Plot\Radar\visulization"
os.makedirs(output_folder, exist_ok=True)
compare_compounds_and_dilutions(neuron_segments_dict, compounds, output_folder, interactive=True,if_combine=False, if_sum_normalization=True)
# Out:
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Benzaldehyde Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Benzaldehyde Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Linalool Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Linalool Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Trans-beta-ionone Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Trans-beta-ionone Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Geraniol Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Geraniol Dilutions (Sum Normalized)
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Benzaldehyde Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Linalool Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Trans-beta-ionone Dilutions
# Warning: Zero variance in some rows. Skipping clustering for Neuronal Responses to Geraniol Dilutions
# (<Figure size 1200x1000 with 1 Axes>,
#  {'c4': <Figure size 1200x1000 with 1 Axes>,
#   'c5': <Figure size 1200x1000 with 1 Axes>,
#   'c6': <Figure size 1200x1000 with 1 Axes>,
#   'c7': <Figure size 1200x1000 with 1 Axes>},
#  {'compounds': Figure({
#       'data': [{'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Benzaldehyde',
#                 'opacity': 0.7,
#                 'r': [0.16330178081989288, 0.09848923981189728, 1.3456722497940063,
#                       0.5045072436332703, 0.07514427602291107, 0.10883888602256775,
#                       0.2188895344734192, 0.013178971596062183, 0.011418281123042107,
#                       0.019421691074967384, 0.029189497232437134,
#                       0.17532441020011902, 0.1631190925836563, 0.11103934049606323,
#                       0.03973475843667984, 0.06411270797252655, 0.0346536748111248,
#                       0.15924590826034546, 0.27149873971939087, 0.05289648473262787,
#                       0.13464508950710297, 0.024151915684342384, 0.16330178081989288],
#                 'theta': [AWCL, AWAL, AWBR, AWBL, ASJR, ASHL, AWCR, ASIL, ASGR,
#                           ADFL, ASIR, ASHR, ADFR, ASGL, AFDR, ADLR, ADLL, ASER, ASKR,
#                           ASJL, ASKL, AWAR, AWCL],
#                 'type': 'scatterpolar'},
#                {'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Linalool',
#                 'opacity': 0.7,
#                 'r': [0.09624262899160385, 0.06487759202718735,
#                       0.044772230088710785, 0.08531685173511505, 0.48172909021377563,
#                       0.14675071835517883, 0.271336168050766, 0.16760598123073578,
#                       0.09202568978071213, 0.07113974541425705, 0.023293092846870422,
#                       0.1356315314769745, 0.07212364673614502, 0.09426337480545044,
#                       0.07158646732568741, 0.1822311133146286, 0.3136877119541168,
#                       0.33845028281211853, 0.3989824652671814, 0.11836537718772888,
#                       0.309346467256546, 0.06628207117319107, 0.09624262899160385],
#                 'theta': [AWCL, AWAL, AWBR, AWBL, ASJR, ASHL, AWCR, ASIL, ASGR,
#                           ADFL, ASIR, ASHR, ADFR, ASGL, AFDR, ADLR, ADLL, ASER, ASKR,
#                           ASJL, ASKL, AWAR, AWCL],
#                 'type': 'scatterpolar'},
#                {'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Trans-beta-ionone',
#                 'opacity': 0.7,
#                 'r': [0.18498170375823975, 0.05093517154455185, 0.2442701756954193,
#                       0.2579788863658905, 0.9854657053947449, 0.25982388854026794,
#                       0.3165517747402191, 0.22946807742118835, 0.027621304616332054,
#                       0.03836878761649132, 0.07150334119796753, 0.1793326437473297,
#                       0.013847291469573975, 0.0031567912083119154,
#                       0.004200342111289501, 0.0028714039362967014,
#                       0.0013210972538217902, 0.25268131494522095, 0.4009038805961609,
#                       0.09359239041805267, 0.24763447046279907, 0.012241196818649769,
#                       0.18498170375823975],
#                 'theta': [AWCL, AWAL, AWBR, AWBL, ASJR, ASHL, AWCR, ASIL, ASGR,
#                           ADFL, ASIR, ASHR, ADFR, ASGL, AFDR, ADLR, ADLL, ASER, ASKR,
#                           ASJL, ASKL, AWAR, AWCL],
#                 'type': 'scatterpolar'},
#                {'fill': 'toself',
#                 'mode': 'lines+markers',
#                 'name': 'Geraniol',
#                 'opacity': 0.7,
#                 'r': [0.05367308855056763, 0.01718727871775627, 0.43584689497947693,
#                       0.39237815141677856, 0.6757200360298157, 0.23901250958442688,
#                       0.3213633894920349, 0.25092607736587524, 0.18226276338100433,
#                       0.20482484996318817, 0.19006255269050598, 0.35740768909454346,
#                       0.1974562257528305, 0.1413932889699936, 0.04171813651919365,
#                       0.1312713325023651, 0.18450398743152618, 0.2503715455532074,
#                       0.15033623576164246, 0.0013427473604679108,
#                       0.14622509479522705, 0.0028274531941860914,
#                       0.05367308855056763],
#                 'theta': [AWCL, AWAL, AWBR, AWBL, ASJR, ASHL, AWCR, ASIL, ASGR,
#                           ADFL, ASIR, ASHR, ADFR, ASGL, AFDR, ADLR, ADLL, ASER, ASKR,
#                           ASJL, ASKL, AWAR, AWCL],
#                 'type': 'scatterpolar'}],
#       'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                   'showarrow': False,
#                                   'text': 'Values represent peak response during stimulus period',
#                                   'x': 0.5,
#                                   'xref': 'paper',
#                                   'y': -0.15,
#                                   'yref': 'paper'}],
#                  'height': 800,
#                  'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                  'polar': {'radialaxis': {'range': [0, 1.4802394747734071], 'visible': True}},
#                  'showlegend': True,
#                  'template': '...',
#                  'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Different Compounds', 'x': 0.5},
#                  'width': 800}
#   }),
#   'dilutions': {'Benzaldehyde': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.019421691074967384, 0.1631190925836563, 0.0346536748111248,
#                        0.06411270797252655, 0.03973475843667984, 0.15924590826034546,
#                        0.11103934049606323, 0.011418281123042107, 0.10883888602256775,
#                        0.17532441020011902, 0.013178971596062183,
#                        0.029189497232437134, 0.05289648473262787, 0.07514427602291107,
#                        0.13464508950710297, 0.27149873971939087, 0.09848923981189728,
#                        0.024151915684342384, 0.5045072436332703, 1.3456722497940063,
#                        0.16330178081989288, 0.2188895344734192, 0.019421691074967384],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 1.4802394747734071], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Benzaldehyde Dilutions', 'x': 0.5},
#                   'width': 800}
#    }),
#    'Linalool': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.07113974541425705, 0.07212364673614502, 0.3136877119541168,
#                        0.1822311133146286, 0.07158646732568741, 0.33845028281211853,
#                        0.09426337480545044, 0.09202568978071213, 0.14675071835517883,
#                        0.1356315314769745, 0.16760598123073578, 0.023293092846870422,
#                        0.11836537718772888, 0.48172909021377563, 0.309346467256546,
#                        0.3989824652671814, 0.06487759202718735, 0.06628207117319107,
#                        0.08531685173511505, 0.044772230088710785, 0.09624262899160385,
#                        0.271336168050766, 0.07113974541425705],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 0.5299019992351532], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Linalool Dilutions', 'x': 0.5},
#                   'width': 800}
#    }),
#    'Trans-beta-ionone': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.03836878761649132, 0.013847291469573975,
#                        0.0013210972538217902, 0.0028714039362967014,
#                        0.004200342111289501, 0.25268131494522095,
#                        0.0031567912083119154, 0.027621304616332054,
#                        0.25982388854026794, 0.1793326437473297, 0.22946807742118835,
#                        0.07150334119796753, 0.09359239041805267, 0.9854657053947449,
#                        0.24763447046279907, 0.4009038805961609, 0.05093517154455185,
#                        0.012241196818649769, 0.2579788863658905, 0.2442701756954193,
#                        0.18498170375823975, 0.3165517747402191, 0.03836878761649132],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 1.0840122759342194], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Trans-beta-ionone Dilutions', 'x': 0.5},
#                   'width': 800}
#    }),
#    'Geraniol': Figure({
#        'data': [{'fill': 'toself',
#                  'mode': 'lines+markers',
#                  'name': 'E4',
#                  'opacity': 0.7,
#                  'r': [0.20482484996318817, 0.1974562257528305, 0.18450398743152618,
#                        0.1312713325023651, 0.04171813651919365, 0.2503715455532074,
#                        0.1413932889699936, 0.18226276338100433, 0.23901250958442688,
#                        0.35740768909454346, 0.25092607736587524, 0.19006255269050598,
#                        0.0013427473604679108, 0.6757200360298157, 0.14622509479522705,
#                        0.15033623576164246, 0.01718727871775627,
#                        0.0028274531941860914, 0.39237815141677856,
#                        0.43584689497947693, 0.05367308855056763, 0.3213633894920349,
#                        0.20482484996318817],
#                  'theta': [ADFL, ADFR, ADLL, ADLR, AFDR, ASER, ASGL, ASGR, ASHL,
#                            ASHR, ASIL, ASIR, ASJL, ASJR, ASKL, ASKR, AWAL, AWAR, AWBL,
#                            AWBR, AWCL, AWCR, ADFL],
#                  'type': 'scatterpolar'}],
#        'layout': {'annotations': [{'font': {'color': 'gray', 'size': 10},
#                                    'showarrow': False,
#                                    'text': 'Values represent peak response during stimulus period',
#                                    'x': 0.5,
#                                    'xref': 'paper',
#                                    'y': -0.15,
#                                    'yref': 'paper'}],
#                   'height': 800,
#                   'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.1, 'yanchor': 'bottom'},
#                   'polar': {'radialaxis': {'range': [0, 0.7432920396327973], 'visible': True}},
#                   'showlegend': True,
#                   'template': '...',
#                   'title': {'font': {'size': 16}, 'text': 'Neuronal Responses to Geraniol Dilutions', 'x': 0.5},
#                   'width': 800}
#    })}})

# %%
heatmap_plot(neuron_segments_dict, compounds, output_folder, if_combine=False)

# %%
from result_analysis.react_time import calculate_time_to_segment_half_peak
time_to_half_peak_results = calculate_time_to_segment_half_peak(neuron_segments_dict)

# %%
from utils.HDF5Toolkit import save_h5file
# save_h5file(r"G:\LAB\CODE\sensory_pipeline\data\neuron_segments.h5", "neuron_segments_dict", mode='w', **neuron_segments_dict)
save_h5file(r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\neuron_segments_dict.h5", "neuron_segments_dict", mode='w', **neuron_segments_dict)

# %%
from utils.HDF5_load import load_h5file
neuron_segments_dict = load_h5file(
    # r"G:\LAB\CODE\sensory_pipeline\data\neuron_segments.h5", 
    r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\neuron_segments_dict.h5",   
    # r"H:\Process_temporary\WJH\olfactory\analysis\coffee_neuron_segments.h5",   
    "neuron_segments_dict"
)

# %%
from result_plot.visweb import create_neuronal_dashboard
app = create_neuronal_dashboard(neuron_segments_dict, compounds)  # Change port if needed
app.run(port=8050, debug=True, jupyter_mode='external')
# Out:
# Dash app running on http://127.0.0.1:8050/
