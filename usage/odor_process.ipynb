# %% [markdown]
# ## Config

# %%
import sys
sys.path.append("..")

# %% [markdown]
# ## Draw neural signals with bioID

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\20250604.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250604\tiffplot\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\ID0604_odor.xlsx",
        "date": "20250604_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\ID0604_odor.xlsx",
        "date": "20250604_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\20250529.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250529\tiffplot\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\ID0529_odor.xlsx",
        "date": "20250529_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\ID0529_odor.xlsx",
        "date": "20250529_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\20250523_The.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250523\tiffplot\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\ID0522_Lthe.xlsx",
        "date": "20250523_Lthe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\ID0522_Lthe.xlsx",
        "date": "20250523_Lthe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\20250515_The.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\0515_Lthe\tiffplot\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\ID0515_Lthe.xlsx",
        "date": "20250515_Lthe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\ID0515_Lthe.xlsx",
        "date": "20250515_Lthe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_EGCG\20250515_EGCG.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_EGCG\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\0515_EGCG\tiffplot\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_EGCG\ID0515_EGCG.xlsx",
        "date": "20250515_EGCG",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "bi_ID_path": r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_EGCG\ID0515_EGCG.xlsx",
        "date": "20250515_EGCG",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)

# %% [markdown]
# ## Load worm data from infer result and ID annotation
# - get stimulus interval info from output_volumes.xlsx
# - get ID data from ID.xlsx
# - get intensity data from HDF5 file
# - detrend and save data in a dictionary

# %%
from data_load.process_worm_data import load_and_process_worm_data

# sorting_config_0604 = {
#     'w3':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w4':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w6':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w7':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w10':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     }
# }

experiment_df_0604_odor, stimulus_lists_0604_odor, ID_info_0604_odor, worm_data_0604_odor, neuron_segments_dict_0604_odor, neuron_segments_dict_reorganized_0604_odor, neuron_groups_0604_odor = load_and_process_worm_data(
    h5_file_path=  r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\20250604.h5",
    # h5_file_path=  r"G:\LAB\DATA\Olfactory\result\20250604\20250604.h5",
    channel_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\output_volumes.xlsx",
    # channel_info_path= r"G:\LAB\DATA\Olfactory\result\20250604\output_volumes.xlsx",
    ID_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\ID0604_odor.xlsx",
    # ID_info_path= r"G:\LAB\DATA\Olfactory\result\20250604\ID0604_odor.xlsx",
    date='20250604',
    sorting_config=None,
)

# %%
# sorting_config_0529 = {
#     'w3':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w4':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w6':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w7':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     },
#     'w10':{
#             'stimulus_sort': [6,7,4,5,2,3,0,1],
#             'buffer_sort': [0,7,8,5,6,3,4,1,2]
#     }
# }

experiment_df_0529_odor, stimulus_lists_0529_odor, ID_info_0529_odor, worm_data_0529_odor, neuron_segments_dict_0529_odor, neuron_segments_dict_reorganized_0529_odor, neuron_groups_0529_odor = load_and_process_worm_data(
        h5_file_path=  r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\20250529.h5",
        # h5_file_path=  r"G:\LAB\DATA\Olfactory\result\20250529\20250529.h5",
        channel_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\output_volumes.xlsx",
        # channel_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\output_volumes.xlsx",
        ID_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\ID0529_odor.xlsx",
        # ID_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\ID0529_odor.xlsx",
        date='20250529',
        sorting_config=None)

# %%
experiment_df_0523_Lthe, stimulus_lists_0523_Lthe, ID_info_0523_Lthe, worm_data_0523_Lthe, neuron_segments_dict_0523_Lthe, neuron_segments_dict_reorganized_0523_Lthe, neuron_groups_0523_Lthe = load_and_process_worm_data(
        h5_file_path=  r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\20250523_The.h5",
        # h5_file_path=  r"G:\LAB\DATA\Olfactory\result\20250529\20250529.h5",
        channel_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\output_volumes.xlsx",
        # channel_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\output_volumes.xlsx",
        ID_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\ID0522_Lthe.xlsx",
        # ID_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\ID0529_odor.xlsx",
        date='20250523',
        sorting_config=None)

# %%
experiment_df_0515_Lthe, stimulus_lists_0515_Lthe, ID_info_0515_Lthe, worm_data_0515_Lthe, neuron_segments_dict_0515_Lthe, neuron_segments_dict_reorganized_0515_Lthe, neuron_groups_0515_Lthe = load_and_process_worm_data(
        h5_file_path=  r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\20250515_The.h5",
        # h5_file_path=  r"G:\LAB\DATA\Olfactory\result\20250529\20250529.h5",
        channel_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\output_volumes.xlsx",
        # channel_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\output_volumes.xlsx",
        ID_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\ID0515_Lthe.xlsx",
        # ID_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\ID0529_odor.xlsx",
        date='20250515',
        sorting_config=None)

# %%
experiment_df_0515_EGCG, stimulus_lists_0515_EGCG, ID_info_0515_EGCG, worm_data_0515_EGCG, neuron_segments_dict_0515_EGCG, neuron_segments_dict_reorganized_0515_EGCG, neuron_groups_0515_EGCG = load_and_process_worm_data(
        h5_file_path=  r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_EGCG\20250515_EGCG.h5",
        # h5_file_path=  r"G:\LAB\DATA\Olfactory\result\20250529\20250529.h5",
        channel_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_EGCG\output_volumes.xlsx",
        # channel_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\output_volumes.xlsx",
        ID_info_path= r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_EGCG\ID0515_EGCG.xlsx",
        # ID_info_path= r"G:\LAB\DATA\Olfactory\result\20250529\ID0529_odor.xlsx",
        date='20250515',
        sorting_config=None)

# %%
from data_load.process_worm_data import merge_multiple_dicts
all_neuron_segments = merge_multiple_dicts(neuron_segments_dict_reorganized_0515_EGCG,
                                               neuron_segments_dict_reorganized_0515_Lthe, neuron_segments_dict_reorganized_0523_Lthe)

# %%
from data_load.process_worm_data import merge_multiple_dicts
all_neuron_segments = merge_multiple_dicts(neuron_segments_dict_reorganized_0604_odor, neuron_segments_dict_reorganized_0529_odor)

# %%
import copy
neuron_segments_dict = copy.deepcopy(all_neuron_segments)

# %%
neuron_segments_dict.keys()

# %%
neuron_segments_dict

# %%
# select distinct keys
keys_to_copy = ['ASKL', 'ASKR', 'ASJL', 'ASJR', 'ASHL', 'ASHR', 'ADFL', 'ADFR', 'ADLL', 'ADLR', 'ASIL', 'ASIR', 'AWAL', 'AWAR', 'AWBL', 'AWBR', 'AWCL', 'AWCR', 'ASGL', 'ASGR', 'ASER']
neuron_segments_dict = {key: copy.deepcopy(neuron_segments_dict[key]) for key in keys_to_copy}
# neuron_groups = {key: copy.deepcopy(neuron_groups[key]) for key in keys_to_copy}

# %% [markdown]
# ## plot

# %%
import json
with open(r'H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json', 'r') as f:
# with open(r'G:\LAB\CODE\sensory_pipeline\data_load\config\odor_info.json', 'r') as f:
# with open(r'G:\LAB\CODE\sensory_pipeline\data_load\config\compound_info.json', 'r') as f:
    compounds = json.load(f)

# %%
from result_plot.draw_signal_pdf_with_ID import plot_neurons_to_pdf
output_pdf = r'G:\LAB\DATA\Olfactory\result\20250529\neuron_segments.pdf'
plot_neurons_to_pdf(neuron_segments_dict, compounds,output_pdf, if_combine=False)

# %%
from result_plot.radar_heatmap_plot import compare_compounds_and_dilutions, heatmap_plot
import os
# output_folder = r"H:\Process_temporary\WJH\olfactory\ID\result\20250428_The\visulization_0513_1"
output_folder = r"I:\WJH\flavor\odor\radar\pair"
os.makedirs(output_folder, exist_ok=True)
compare_compounds_and_dilutions(neuron_segments_dict, compounds, output_folder, interactive=True,if_combine=False, if_sum_normalization=True)

# %%
output_folder = r"I:\WJH\flavor\odor\Heatmap\pair"
heatmap_plot(neuron_segments_dict, compounds, output_folder, if_combine=False)

# %%
from result_analysis.react_time import calculate_time_to_segment_half_peak
time_to_half_peak_results = calculate_time_to_segment_half_peak(neuron_segments_dict)

# %%
from utils.HDF5Toolkit import save_h5file
# save_h5file(r"G:\LAB\CODE\sensory_pipeline\data\neuron_segments.h5", "neuron_segments_dict", mode='w', **neuron_segments_dict)
save_h5file(r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\neuron_segments_dict.h5", "neuron_segments_dict", mode='w', **neuron_segments_dict)

# %%
from utils.HDF5_load import load_h5file
neuron_segments_dict = load_h5file(
    # r"G:\LAB\CODE\sensory_pipeline\data\neuron_segments.h5", 
    r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\neuron_segments_dict.h5",   
    # r"H:\Process_temporary\WJH\olfactory\analysis\coffee_neuron_segments.h5",   
    "neuron_segments_dict"
)

# %%
from result_plot.visweb import create_neuronal_dashboard
app = create_neuronal_dashboard(neuron_segments_dict, compounds)  # Change port if needed
app.run(port=8052, debug=True, jupyter_mode='external')
