# %% [markdown]
# # check ID using napari

# %% [markdown]
# ## module load

# %%
import numpy as np
import sys
sys.path.append("../")
sys.path.append("./python/")
sys.path.append("./")
from id_identify.box_region_npy import box_region_npy 

def image_process(image_np, background_value = 110):
    """
    Denoise
    """
    image_np = image_np.astype(np.float32)  # Convert to float
    image_np[image_np < background_value] = 0  # Set background pixels to 0
    return image_np

# %%
import sys
sys.path.append("../")
sys.path.append("./python/")
sys.path.append("./")
from id_identify.id_identify_in_napari import id_identify_in_napari

# %% [markdown]
# ## 04

# %% [markdown]
# ### 0421_EGCG

# %%
# w1
w1_green_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG\w2\green.npy"
w1_red_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG\w2\red.npy"
w1_green = np.load(w1_green_path)
w1_red = np.load(w1_red_path)

# %%
w1_green = image_process(w1_green, background_value=110)
w1_red = image_process(w1_red, background_value=110)

# %%
w1_red = np.flip(w1_red, axis=3)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w1_green[:1], name='w1_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w1_red[:1], name='w1_red', colormap='red',blending='additive', scale=[1,5,1,1])

# %%
# w2
w2_green_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250421_EGCG\w2\green.npy"
w2_red_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250421_EGCG\w2\red.npy"
w2_green = np.load(w2_green_path)
w2_red = np.load(w2_red_path)

# %%
w2_red = np.flip(w2_red, axis=3)
w2_green = image_process(w2_green, background_value=110)
w2_red = image_process(w2_red, background_value=110)

# %%
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\infer_result\20250421_EGCG\w2\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 20/20 [00:00<00:00, 86.42it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w2_green[:2], name='w2_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w2_red[:2], name='w2_red', colormap='red',blending='additive', scale=[1,5,1,1])
viewer.add_labels(mask, name='mask', blending='additive', scale=[1,5,1,1])

# %%
del w1_green, w1_red, w2_green, w2_red

# %%
# w3
w3_green_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG\w3\green.npy"
w3_red_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG\w3\red.npy"
w3_green = np.load(w3_green_path)
w3_red = np.load(w3_red_path)
w3_red = np.flip(w3_red, axis=3)
w3_green = image_process(w3_green, background_value=110)
w3_red = image_process(w3_red, background_value=110)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w3_green[:1], name='w3_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w3_red[:1], name='w3_red', colormap='red',blending='additive', scale=[1,5,1,1])

# %%
# w3 is a good example for inclined posture
del w3_green, w3_red

# %%
# w6
w6_green_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG\w6\green.npy"
w6_red_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG\w6\red.npy"
w6_green = np.load(w6_green_path)
w6_red = np.load(w6_red_path)
w6_red = np.flip(w6_red, axis=3)
w6_green = image_process(w6_green, background_value=110)
w6_red = image_process(w6_red, background_value=110)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w6_green[:1], name='w6_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w6_red[:1], name='w6_red', colormap='red',blending='additive', scale=[1,5,1,1])

# %%
del w6_green, w6_red

# %% [markdown]
# ### 0421_EGCG_high

# %%
# w2
w2_green_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG_high\w2_2025-04-21_18-00-51\green.npy"
w2_red_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250421_EGCG_high\w2_2025-04-21_18-00-51\red.npy"
w2_green = np.load(w2_green_path)
w2_red = np.load(w2_red_path)
w2_red = np.flip(w2_red, axis=3)
w2_green = image_process(w2_green, background_value=110)
w2_red = image_process(w2_red, background_value=110)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w2_green[:1], name='w2_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w2_red[:1], name='w2_red', colormap='red',blending='additive', scale=[1,5,1,1])

# %%
# very hard to identify because there are 3 groups of this trial
del w2_green, w2_red

# %% [markdown]
# ### 0428_TF

# %%
# w1
w1_green_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250428_TF\w1_2025-04-28_14-22-35\green.npy"
w1_red_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250428_TF\w1_2025-04-28_14-22-35\red.npy"
w1_green = np.load(w1_green_path)
w1_red = np.load(w1_red_path)
w1_red = np.flip(w1_red, axis=3)
w1_green = image_process(w1_green, background_value=110)
w1_red = image_process(w1_red, background_value=110)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w1_green[:1], name='w1_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w1_red[:1], name='w1_red', colormap='red',blending='additive', scale=[1,5,1,1])

# %%
del w1_green, w1_red

# %%
# w2
w2_green_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250428_TF\w2_2025-04-28_14-44-02\green.npy"
w2_red_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250428_TF\w2_2025-04-28_14-44-02\red.npy"
w2_green = np.load(w2_green_path)
w2_red = np.load(w2_red_path)
w2_red = np.flip(w2_red, axis=3)
w2_green = image_process(w2_green, background_value=110)
w2_red = image_process(w2_red, background_value=110)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w2_green[:1], name='w2_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w2_red[:1], name='w2_red', colormap='red',blending='additive', scale=[1,5,1,1])

# %%
del w2_green, w2_red

# %%
# w3
w3_green_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250428_TF\w3_2025-04-28_15-14-33\green.npy"
w3_red_path = r"G:\LAB\CODE\sensory_pipeline\ID\image_data\20250428_TF\w3_2025-04-28_15-14-33\red.npy"
w3_green = np.load(w3_green_path)
w3_red = np.load(w3_red_path)
w3_red = np.flip(w3_red, axis=3)
w3_green = image_process(w3_green, background_value=110)
w3_red = image_process(w3_red, background_value=110)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w3_green[:1], name='w3_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w3_red[:1], name='w3_red', colormap='red',blending='additive', scale=[1,5,1,1])

# %%
del w3_green, w3_red

# %% [markdown]
# ### 0428_The

# %%
# w2
w2_green_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w2_2025-04-28_20-50-33\green.npy"
w2_red_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w2_2025-04-28_20-50-33\red.npy"
w2_green = np.load(w2_green_path)
w2_red = np.load(w2_red_path)
w2_red = np.flip(w2_red, axis=3)
w2_green = image_process(w2_green, background_value=110)
w2_red = image_process(w2_red, background_value=110)

# %%
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w2_2025-04-28_20-50-33\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 21/21 [00:00<00:00, 104.17it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w2_green[:1], name='w2_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w2_red[:1], name='w2_red', colormap='red',blending='additive', scale=[1,5,1,1])
viewer.add_labels(mask, name='mask', blending='additive', scale=[1,5,1,1])
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2226+365 (frame: 1102x699+2218+334) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2225+358 (frame: 883x566+2217+327) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# <Labels layer 'mask' at 0x20d8d39c7f0>

# %%
viewer.layers['mask'].data = mask

# %%
del w2_green, w2_red

# %%
# w3
w3_green_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w3_2025-04-28_21-16-17\green.npy"
w3_red_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w3_2025-04-28_21-16-17\red.npy"
w3_green = np.load(w3_green_path)
w3_red = np.load(w3_red_path)
w3_red = np.flip(w3_red, axis=3)
w3_green = image_process(w3_green, background_value=110)
w3_red = image_process(w3_red, background_value=110)

# %%
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w3_2025-04-28_21-16-17\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w3 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 18/18 [00:00<00:00, 132.10it/s]

# %%
# import napari
viewer = napari.Viewer()
viewer.add_image(w3_green[:1], name='w3_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w3_red[:1], name='w3_red', colormap='red',blending='additive', scale=[1,5,1,1])
# Out:
# <Image layer 'w3_red' at 0x1e990c83e80>

# %%
viewer.add_labels(mask_w3, name='mask_w3', blending='additive', scale=[1,5,1,1])
# Out:
# <Labels layer 'mask_w3' at 0x20db6717700>
# e:\Anaconda\envs\cbmi_post\lib\site-packages\napari\layers\labels\labels.py:883: UserWarning: Contours are not displayed during 3D rendering
#   warnings.warn(

# %%
# w4
w4_green_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w4_2025-04-28_21-36-58\green.npy"
w4_red_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w4_2025-04-28_21-36-58\red.npy"
w4_green = np.load(w4_green_path)
w4_red = np.load(w4_red_path)
w4_red = np.flip(w4_red, axis=3)
w4_green = image_process(w4_green, background_value=110)
w4_red = image_process(w4_red, background_value=110)

# %%
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w4_2025-04-28_21-36-58\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w4 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 22/22 [00:00<00:00, 106.89it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w4_green[:1], name='w4_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w4_red[:1], name='w4_red', colormap='red',blending='additive', scale=[1,5,1,1])
viewer.add_labels(mask_w4, name='mask_w4', blending='additive', scale=[1,5,1,1])
# Out:
# <Labels layer 'mask_w4' at 0x1e996bd7a60>

# %%
del w4_green, w4_red

# %%
# w5
w5_green_file = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w5_2025-04-28_22-00-26\green.npy"
w5_red_file = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w5_2025-04-28_22-00-26\red.npy"
w5_green = np.load(w5_green_file)
w5_red = np.load(w5_red_file)

# %%
w5_red = np.flip(w5_red, axis=3)

# %%
w5_green = image_process(w5_green)
w5_red = image_process(w5_red)

# %%
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w5_2025-04-28_22-00-26\all_neuron_pt_tuple.npy")

# %%
output_shape = (2,18,1024,1024)
mask_w5 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 22/22 [00:00<00:00, 100.71it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w5_green[:2], name='w5_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w5_red[:2], name='w5_red', colormap='red',blending='additive', scale=[1,5,1,1])
viewer.add_labels(mask_w5, name='mask_w5', blending='additive', scale=[1,5,1,1])
# Out:
# <Labels layer 'mask_w5' at 0x1e989df4b20>

# %%
# w6
w6_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w6_2025-04-28_22-12-25\green.npy")
w6_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w6_2025-04-28_22-12-25\red.npy")
w6_red = np.flip(w6_red, axis=3)
w6_green = image_process(w6_green)
w6_red = image_process(w6_red)

# %%
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250428_compararison\w6_2025-04-28_22-12-25\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w6 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 19/19 [00:00<00:00, 112.28it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w6_green[:2], name='w6_green', colormap='green', blending= 'additive',scale=[1,5,1,1])
viewer.add_image(w6_red[:2], name='w6_red', colormap='red',blending='additive', scale=[1,5,1,1])
viewer.add_labels(mask_w6, name='mask_w6', blending='additive', scale=[1,5,1,1])
# Out:
# <Labels layer 'mask_w6' at 0x1e98f8e6a30>

# %% [markdown]
# ## 05

# %% [markdown]
# ### 0515_EGCG

# %%
# w1
w1_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w1_2025-05-15_13-43-47\green.npy")
w1_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w1_2025-05-15_13-43-47\red.npy")
w1_red = np.flip(w1_red, axis=3)
w1_green = image_process(w1_green)
w1_red = image_process(w1_red)

# %%
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w1_2025-05-15_13-43-47\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w1 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 19/19 [00:00<00:00, 154.28it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w1_green, name='w1_green', colormap='green', blending= 'additive',scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w1_red, name='w1_red', colormap='red',blending='additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_labels(mask_w1, name='mask_w1', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w1' at 0x1c1a808ecd0>

# %%
# w2
w2_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w2_2025-05-15_14-13-28\green.npy")
w2_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w2_2025-05-15_14-13-28\red.npy")
w2_red = np.flip(w2_red, axis=3)
w2_green = image_process(w2_green)
w2_red = image_process(w2_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w2_2025-05-15_14-13-28\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w2 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 16/16 [00:00<00:00, 128.00it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w2_green, name='w2_green', colormap='green', blending= 'additive',scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w2_red, name='w2_red', colormap='red',blending='additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_labels(mask_w2, name='mask_w2', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w2' at 0x1c1c9ee8fa0>

# %%
#w4
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w4_2025-05-15_15-21-42\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w4_2025-05-15_15-21-42\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w4_2025-05-15_15-21-42\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w4_2025-05-15_15-21-42\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w4",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 33/33 [00:00<00:00, 84.92it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2213+639 (frame: 1102x699+2205+608) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2212+632 (frame: 883x566+2204+601) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 550x605+2212+632 (frame: 568x652+2203+594) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY2". Resulting geometry: 690x758+2213+639 (frame: 708x805+2204+601) margins: 9, 38, 9, 9 minimum size: 385x518 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=403,565 maxtrack=0,0)

# %%
#w5
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w5_2025-05-15_15-47-09\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w5_2025-05-15_15-47-09\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w5_2025-05-15_15-47-09\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w5_2025-05-15_15-47-09\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w5",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 21/21 [00:00<00:00, 79.28it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2376+929 (frame: 1102x699+2368+898) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2375+922 (frame: 883x566+2367+891) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# WARNING:vispy:QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2376+929 (frame: 1102x699+2368+898) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2375+922 (frame: 883x566+2367+891) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# ...

# %%
viewer.layers['green'].data[:,:10] = 0
viewer.layers['red'].data[:,:10] = 0

# %%
#w6
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w6_2025-05-15_17-19-47\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w6_2025-05-15_17-19-47\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w6_2025-05-15_17-19-47\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w6_2025-05-15_17-19-47\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w6",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 23/23 [00:00<00:00, 91.92it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2531+215 (frame: 1102x699+2523+184) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2530+208 (frame: 883x566+2522+177) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
#w7
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w7_2025-05-15_18-53-59\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w7_2025-05-15_18-53-59\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w7_2025-05-15_18-53-59\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w7_2025-05-15_18-53-59\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w7",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 21/21 [00:00<00:00, 73.05it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2531+215 (frame: 1102x699+2523+184) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2530+208 (frame: 883x566+2522+177) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
#w8
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w8_2025-05-15_19-21-43\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w8_2025-05-15_19-21-43\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w8_2025-05-15_19-21-43\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w8_2025-05-15_19-21-43\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w8",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 31/31 [00:00<00:00, 106.27it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2472+481 (frame: 1102x699+2464+450) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2471+474 (frame: 883x566+2463+443) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
#w9
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w9_2025-05-15_19-50-23\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w9_2025-05-15_19-50-23\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w9_2025-05-15_19-50-23\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w9_2025-05-15_19-50-23\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w9",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 20/20 [00:00<00:00, 136.32it/s]

# %%
#w10
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w10_2025-05-15_20-12-41\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w10_2025-05-15_20-12-41\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w10_2025-05-15_20-12-41\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\w10_2025-05-15_20-12-41\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w10",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 27/27 [00:00<00:00, 96.28it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2240+461 (frame: 1102x699+2232+430) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2239+454 (frame: 883x566+2231+423) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# WARNING:vispy:QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2240+461 (frame: 1102x699+2232+430) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2239+454 (frame: 883x566+2231+423) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# ...

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w10_green, name='w10_green', colormap='green', blending= 'additive',scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w10_red, name='w10_red', colormap='red', blending= 'additive',scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_labels(mask_w10, name='mask_w10', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w10' at 0x20f9e0c9af0>

# %% [markdown]
# ### 0515_Lthe

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\20250515_The.h5"
import h5py
from result_plot.draw_signal_no_ID import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

# %%
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\Labjack\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\{key}\plot"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w1\plot\w1_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w1\plot\w1_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w2\plot\w2_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w2\plot\w2_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w3\plot\w3_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w3\plot\w3_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w4\plot\w4_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250515_The\w4\plot\w4_raw_neuron_signals.png

# %%
# w1
w1_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w1_2025-05-15_21-50-19\green.npy")
w1_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w1_2025-05-15_21-50-19\red.npy")
# w1_red = np.flip(w1_red, axis=3)
w1_green = image_process(w1_green)
w1_red = image_process(w1_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w1_2025-05-15_21-50-19\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w1 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 26/26 [00:00<00:00, 89.07it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w1_green, name='w1_green', colormap='green', blending= 'additive',scale=[1,5,1,1],contrast_limits=[120,250])
viewer.add_image(w1_red, name='w1_red', colormap='red', blending= 'additive',scale=[1,5,1,-1] , translate=(0, 0, -5, 1024-5), contrast_limits=[120,250])
viewer.add_labels(mask_w1, name='mask_w1', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w1' at 0x1f497561970>

# %%
# w2
w2_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w2_2025-05-15_22-15-31\green.npy")
w2_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w2_2025-05-15_22-15-31\red.npy")
# w2_red = np.flip(w2_red, axis=3)
w2_green = image_process(w2_green)
w2_red = image_process(w2_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w2_2025-05-15_22-15-31\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w2 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 27/27 [00:00<00:00, 144.38it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w2_green, name='w2_green', colormap='green', blending= 'additive', scale=[1,5,1,1], contrast_limits= [120,250])
viewer.add_image(w2_red, name='w2_red', colormap='red', blending='additive', scale=[1,5,1,-1], translate=[0,0,-5,1024-5], contrast_limits=[120,250])
viewer.add_labels(mask_w2, name='mask_w2', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w2' at 0x1f503b23cd0>

# %%
# w3
w3_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w3_2025-05-15_22-39-12\green.npy")
w3_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w3_2025-05-15_22-39-12\red.npy")
# w3_red = np.flip(w3_red, axis=3)
w3_green = image_process(w3_green)
w3_red = image_process(w3_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w3_2025-05-15_22-39-12\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w3 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 26/26 [00:00<00:00, 62.83it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w3_green, name='w3_green', colormap='green', blending= 'additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w3_red, name='w3_red', colormap='red', blending='additive', scale=[1,5,1,-1], translate=[0,0,-5,1024-5], contrast_limits=[120,250])
viewer.add_labels(mask_w3, name='mask_w3', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2250+501 (frame: 1102x699+2242+470) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2249+494 (frame: 883x566+2241+463) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# <Labels layer 'mask_w3' at 0x1f494936c40>

# %%
# w4
w4_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w4_2025-05-15_23-10-25\green.npy")
w4_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w4_2025-05-15_23-10-25\red.npy")
# w4_red = np.flip(w4_red, axis=3)
w4_green = image_process(w4_green)
w4_red = image_process(w4_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\w4_2025-05-15_23-10-25\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w4 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 30/30 [00:00<00:00, 93.58it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w4_green, name='w4_green', colormap='green', blending= 'additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w4_red, name='w4_red', colormap='red', blending='additive', scale=[1,5,1,-1], translate=[0,0,5,1024+5], contrast_limits=[120,250])
viewer.add_labels(mask_w4, name='mask_w4', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w4' at 0x1f497780ac0>

# %% [markdown]
# ### 0522_L-The

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\20250523_The.h5"
import h5py
from result_plot.draw_signal_no_ID import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

# %%
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\labjack\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"H:\Process_temporary\WJH\olfactory\infer_result\20250523\{key}\plot"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w1\plot\w1_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w1\plot\w1_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w2\plot\w2_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w2\plot\w2_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w3\plot\w3_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w3\plot\w3_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w4\plot\w4_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250523\w4\plot\w4_raw_neuron_signals.png
# ...

# %%
# w1
w1_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w1_2025-05-22_14-23-28\green.npy")
w1_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w1_2025-05-22_14-23-28\red.npy")
# w1_red = np.flip(w1_red, axis=3)
w1_green = image_process(w1_green)
w1_red = image_process(w1_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w1_2025-05-22_14-23-28\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w1 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 33/33 [00:00<00:00, 80.41it/s]

# %%
w1_aligned_volume_npy = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w1_2025-05-22_14-23-28\aligned_volumes_mip.npy")
w1_green[1] = w1_aligned_volume_npy.transpose(2,0,1)

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w1_green, name='w1_green', colormap='green', blending= 'additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w1_red, name='w1_red', colormap='red', blending='additive', scale=[1,5,1,-1], translate=[0,0,-5,1024-5], contrast_limits=[120,250])
viewer.add_labels(mask_w1, name='mask_w1', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w1' at 0x1471da15e50>

# %%
# w2
w2_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w2_2025-05-22_15-05-47\green.npy")
w2_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w2_2025-05-22_15-05-47\red.npy")
w2_aligned_volume_npy = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w2_2025-05-22_15-05-47\aligned_volumes_mip.npy")
w2_green[1] = w2_aligned_volume_npy.transpose(2,0,1)
# w2_red = np.flip(w2_red, axis=3)
w2_green = image_process(w2_green)
w2_red = image_process(w2_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w2_2025-05-22_15-05-47\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w2 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 23/23 [00:00<00:00, 101.55it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w2_green, name='w2_green', colormap='green', blending= 'additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w2_red, name='w2_red', colormap='red', blending='additive', scale=[1,5,1,-1], translate=[0,0,-5,1024-5], contrast_limits=[120,250])
viewer.add_labels(mask_w2, name='mask_w2', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2223+673 (frame: 1102x699+2215+642) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2222+666 (frame: 883x566+2214+635) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# <Labels layer 'mask_w2' at 0x1471e20ad60>

# %%
# w3
w3_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w3_2025-05-22_15-29-17\green.npy")
w3_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w3_2025-05-22_15-29-17\red.npy")
w3_aligned_volume_npy = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w3_2025-05-22_15-29-17\aligned_volumes_mip.npy")
w3_green[1] = w3_aligned_volume_npy.transpose(2,0,1)
# w3_red = np.flip(w3_red, axis=3)
w3_green = image_process(w3_green)
w3_red = image_process(w3_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w3_2025-05-22_15-29-17\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w3 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 30/30 [00:00<00:00, 86.64it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w3_green, name='w3_green', colormap='green', blending= 'additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w3_red, name='w3_red', colormap='red', blending='additive', scale=[1,5,1,-1], translate=[0,0,-5,1024-5], contrast_limits=[120,250])
viewer.add_labels(mask_w3, name='mask_w3', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w3' at 0x1471da5aeb0>

# %%
# w4
w4_green = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w4_2025-05-22_15-53-46\green.npy")
w4_red = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w4_2025-05-22_15-53-46\red.npy")
aligned_volume_npy = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w4_2025-05-22_15-53-46\aligned_volumes_mip.npy")
w4_green[1] = aligned_volume_npy.transpose(2,0,1)

w4_green = image_process(w4_green)
w4_red = image_process(w4_red)
neuron_pt_tuple = np.load(r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w4_2025-05-22_15-53-46\all_neuron_pt_tuple.npy")
output_shape = (2,18,1024,1024)
mask_w4 = box_region_npy(neuron_pt_tuple[:2],output_shape=output_shape, if_save=False)
# Out:
# Processing neuron boxes: 100%|██████████| 26/26 [00:00<00:00, 89.44it/s]

# %%
import napari
viewer = napari.Viewer()
viewer.add_image(w4_green, name='w4_green', colormap='green', blending= 'additive', scale=[1,5,1,1], contrast_limits=[120,250])
viewer.add_image(w4_red, name='w4_red', colormap='red', blending='additive', scale=[1,5,1,-1], translate=[0,0,-5,1024-5], contrast_limits=[120,250])
viewer.add_labels(mask_w4, name='mask_w4', blending='additive', scale=[1,5,1,1], opacity=1.0)
# Out:
# <Labels layer 'mask_w4' at 0x14727302f70>

# %%
green_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w5_2025-05-22_16-37-58\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w5_2025-05-22_16-37-58\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w5_2025-05-22_16-37-58\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w5_2025-05-22_16-37-58\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w5",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 21/21 [00:00<00:00, 74.30it/s]

# %%
green_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w6_2025-05-22_17-04-57\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w6_2025-05-22_17-04-57\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w6_2025-05-22_17-04-57\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w6_2025-05-22_17-04-57\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w6",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 23/23 [00:00<00:00, 86.05it/s]

# %%
green_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w7_2025-05-22_17-26-18\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w7_2025-05-22_17-26-18\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w7_2025-05-22_17-26-18\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\w7_2025-05-22_17-26-18\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w7",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 22/22 [00:00<00:00, 96.60it/s]

# %% [markdown]
# ### 0529 Odor

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\20250529.h5"
import h5py
from result_plot.draw_signal_no_ID import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

# %%
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\labjack\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"H:\Process_temporary\WJH\olfactory\infer_result\20250529\{key}\plot"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250529_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250529_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250529\w2\plot\w2_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250529\w2\plot\w2_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250529\w3\plot\w3_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250529\w3\plot\w3_raw_neuron_signals.png
# dfof signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250529\w4\plot\w4_dfof_neuron_signals.png
# Raw signal plot saved to H:\Process_temporary\WJH\olfactory\infer_result\20250529\w4\plot\w4_raw_neuron_signals.png

# %%
green_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w2_2025-05-29_17-07-57\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w2_2025-05-29_17-07-57\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w2_2025-05-29_17-07-57\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w2_2025-05-29_17-07-57\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w2",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 27/27 [00:00<00:00, 99.94it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2777+1020 (frame: 1102x699+2769+989) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2776+1013 (frame: 883x566+2768+982) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w3_2025-05-29_17-22-43\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w3_2025-05-29_17-22-43\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w3_2025-05-29_17-22-43\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w3_2025-05-29_17-22-43\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w3",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 22/22 [00:00<00:00, 90.18it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2777+1020 (frame: 1102x699+2769+989) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2776+1013 (frame: 883x566+2768+982) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w4_2025-05-29_17-36-26\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w4_2025-05-29_17-36-26\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w4_2025-05-29_17-36-26\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\w4_2025-05-29_17-36-26\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w4",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 13/13 [00:00<00:00, 150.05it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2777+1020 (frame: 1102x699+2769+989) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2776+1013 (frame: 883x566+2768+982) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %% [markdown]
# ## 06

# %% [markdown]
# ### 0604_Odor

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\20250604.h5"
import h5py
from result_plot.draw_signal_no_ID import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\labjack\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"H:\{key}\plot"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250529_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250529_odor",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to H:\w1\plot\w1_dfof_neuron_signals.png
# Raw signal plot saved to H:\w1\plot\w1_raw_neuron_signals.png
# dfof signal plot saved to H:\w10\plot\w10_dfof_neuron_signals.png
# Raw signal plot saved to H:\w10\plot\w10_raw_neuron_signals.png
# dfof signal plot saved to H:\w2\plot\w2_dfof_neuron_signals.png
# Raw signal plot saved to H:\w2\plot\w2_raw_neuron_signals.png
# dfof signal plot saved to H:\w3\plot\w3_dfof_neuron_signals.png
# Raw signal plot saved to H:\w3\plot\w3_raw_neuron_signals.png
# dfof signal plot saved to H:\w4\plot\w4_dfof_neuron_signals.png
# Raw signal plot saved to H:\w4\plot\w4_raw_neuron_signals.png
# dfof signal plot saved to H:\w5\plot\w5_dfof_neuron_signals.png
# Raw signal plot saved to H:\w5\plot\w5_raw_neuron_signals.png
# dfof signal plot saved to H:\w6\plot\w6_dfof_neuron_signals.png
# Raw signal plot saved to H:\w6\plot\w6_raw_neuron_signals.png
# dfof signal plot saved to H:\w7\plot\w7_dfof_neuron_signals.png
# ...

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w1_2025-06-04_15-14-50\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w1_2025-06-04_15-14-50\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w1_2025-06-04_15-14-50\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w1_2025-06-04_15-14-50\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w1",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 41/41 [00:00<00:00, 91.06it/s]

# %%
# temp_green = viewer.layers['green'].data 
viewer.layers['green'].data = temp_green

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w2_2025-06-04_15-35-08\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w2_2025-06-04_15-35-08\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w2_2025-06-04_15-35-08\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w2_2025-06-04_15-35-08\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w2",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 38/38 [00:00<00:00, 95.53it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2198+628 (frame: 1102x699+2190+597) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2197+621 (frame: 883x566+2189+590) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w3_2025-06-04_15-47-34\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w3_2025-06-04_15-47-34\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w3_2025-06-04_15-47-34\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w3_2025-06-04_15-47-34\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w3",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 30/30 [00:00<00:00, 92.27it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2198+628 (frame: 1102x699+2190+597) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2197+621 (frame: 883x566+2189+590) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w4_2025-06-04_17-00-50\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w4_2025-06-04_17-00-50\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w4_2025-06-04_17-00-50\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w4_2025-06-04_17-00-50\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w4",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 25/25 [00:00<00:00, 111.40it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2198+628 (frame: 1102x699+2190+597) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2197+621 (frame: 883x566+2189+590) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w5_2025-06-04_17-26-18\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w5_2025-06-04_17-26-18\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w5_2025-06-04_17-26-18\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w5_2025-06-04_17-26-18\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w5",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 25/25 [00:00<00:00, 71.67it/s]

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w7_2025-06-04_17-57-03\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w7_2025-06-04_17-57-03\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w7_2025-06-04_17-57-03\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w7_2025-06-04_17-57-03\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w7",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 24/24 [00:00<00:00, 103.83it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2177+462 (frame: 1102x699+2169+431) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2176+455 (frame: 883x566+2168+424) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w8_2025-06-04_18-25-46\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w8_2025-06-04_18-25-46\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w8_2025-06-04_18-25-46\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w8_2025-06-04_18-25-46\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w8",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 25/25 [00:00<00:00, 89.55it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2376+929 (frame: 1102x699+2368+898) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2375+922 (frame: 883x566+2367+891) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# WARNING:vispy:QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2376+929 (frame: 1102x699+2368+898) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2375+922 (frame: 883x566+2367+891) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)
# WARNING: QThread: Destroyed while thread is still running

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w9_2025-06-04_18-45-47\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w9_2025-06-04_18-45-47\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w9_2025-06-04_18-45-47\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w9_2025-06-04_18-45-47\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w9",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 33/33 [00:00<00:00, 98.15it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2177+462 (frame: 1102x699+2169+431) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2176+455 (frame: 883x566+2168+424) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %%
temp_green = viewer.layers['green'].data 
viewer.layers['green'].data[:,9:] = 0

# %%
green_file_path =r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w10_2025-06-04_18-58-44\green.npy"
red_file_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w10_2025-06-04_18-58-44\red.npy"
aligned_volume_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w10_2025-06-04_18-58-44\aligned_volumes_mip.npy"
neuron_pt_tuple_path = r"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\w10_2025-06-04_18-58-44\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name="w10",
                        green_scale=[1,5,1,1],
                        red_translate=[0,0,-5,1024-5],
                        red_scale=[1, 5, 1, -1],
                        mask_scale=[1, 5, 1, 1])
# Out:
# Processing neuron boxes: 100%|██████████| 24/24 [00:00<00:00, 94.56it/s]
