# %% [markdown]
# # check ID using napari

# %% [markdown]
# ## module load

# %%
import sys
sys.path.append("../")
sys.path.append("./python/")
sys.path.append("./")
from id_identify.id_identify_in_napari import id_identify_in_napari

# %% [markdown]
# ## 04

# %% [markdown]
# ### 0421_EGCG

# %% [markdown]
# ### 0421_EGCG_high

# %% [markdown]
# ### 0428_TF

# %% [markdown]
# ### 0428_The

# %% [markdown]
# ### 0428_Caffeine

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250429_caffeine\20250429_caffeine.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250429_caffeine\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250429_caffeine\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# h:\Process_temporary\WJH\sensory_pipeline_python\id_identify\..\data_load\curve_fit.py:234: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(double_exponential, x_data, y_data, p0=initial_guess, maxfev=10000)
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250429_caffeine\w1\w1_dfof_neuron_signals.png
# h:\Process_temporary\WJH\sensory_pipeline_python\id_identify\..\data_load\curve_fit.py:234: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(double_exponential, x_data, y_data, p0=initial_guess, maxfev=10000)
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250429_caffeine\w1\w1_raw_neuron_signals.png
# h:\Process_temporary\WJH\sensory_pipeline_python\id_identify\..\data_load\curve_fit.py:234: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(double_exponential, x_data, y_data, p0=initial_guess, maxfev=10000)
# ...

# %%
worm_number = "w1"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\synthetic_volume\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\synthetic_volume\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)

# %% [markdown]
# ## 05

# %% [markdown]
# ### 0515_EGCG

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\20250515_The.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\Labjack\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\0515_Lthe\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)

# %%
worm_number = "w10"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\synthetic_volume\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_EGCG\{worm_number}\synthetic_volume\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 27/27 [00:00<00:00, 106.21it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2135+530 (frame: 1102x699+2127+499) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2134+523 (frame: 883x566+2126+492) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %% [markdown]
# ### 0515_Lthe

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\20250515_The.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250515_Lthe\Labjack\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\0515_Lthe\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w1\w1_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w1\w1_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w2\w2_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w2\w2_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w3\w3_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w3\w3_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w4\w4_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\0515_Lthe\w4\w4_raw_neuron_signals.png

# %%
worm_number = "w4"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\{worm_number}\synthetic_volume\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250515_LThe\{worm_number}\synthetic_volume\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 35/35 [00:00<00:00, 109.27it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 3202x1415+1794+486 (frame: 3218x1454+1786+455) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 2560x1131+1793+479 (frame: 2576x1170+1785+448) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %% [markdown]
# ### 0522_L-The

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\20250523_The.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

# %%
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\labjack\output_volumes.xlsx"
bio_ID_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250523\ID0522_Lthe.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250523\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250515_LThe",
        "labjack_excel_path": labjack_excel_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250523\w1\w1_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250523\w1\w1_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250523\w2\w2_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250523\w2\w2_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250523\w3\w3_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250523\w3\w3_raw_neuron_signals.png

# %%
worm_number = "w7"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\{worm_number}\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250522_LThe\{worm_number}\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 22/22 [00:00<00:00, 129.78it/s]

# %% [markdown]
# ### 0529 Odor

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\20250529.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

# %%
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\labjack\output_volumes.xlsx"
bio_ID_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250529\ID_0529_odor.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250529\{key}\plot"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250529_odor",
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250529_odor",
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250529\w1\plot\w1_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250529\w1\plot\w1_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250529\w2\plot\w2_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250529\w2\plot\w2_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250529\w3\plot\w3_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250529\w3\plot\w3_raw_neuron_signals.png

# %%
worm_number = "w4"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\{worm_number}\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250529_Odor\{worm_number}\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 13/13 [00:00<00:00, 207.77it/s]

# %% [markdown]
# ## 06

# %% [markdown]
# ### 0604_Odor

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\20250604.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\labjack\output_volumes.xlsx"
bio_ID_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250604\ID0604_odor.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250604\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250604_odor",
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "bi_ID_path": bio_ID_path,
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250604_odor",
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "bi_ID_path": bio_ID_path,
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250604\w1\w1_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250604\w1\w1_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250604\w10\w10_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250604\w10\w10_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250604\w2\w2_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250604\w2\w2_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250604\w3\w3_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250604\w3\w3_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250604\w4\w4_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250604\w4\w4_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250604\w5\w5_dfof_neuron_signals.png
# ...

# %%
worm_number = "w1"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\{worm_number}\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250604_Odor\{worm_number}\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 41/41 [00:00<00:00, 99.70it/s]

# %% [markdown]
# ## 07

# %% [markdown]
# ### 0705_wen0065_1octanol_isoamyl_alcohol_EGCG_LTHe

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250705\20250705.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250705\labjack\output_volumes.xlsx"
bio_ID_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250705\ID0705_odor.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250705\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250705_odor",
        "bi_ID_path": bio_ID_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250705_odor",
        "bi_ID_path": bio_ID_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250705\w1\w1_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250705\w1\w1_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250705\w2\w2_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250705\w2\w2_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250705\w3\w3_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250705\w3\w3_raw_neuron_signals.png

# %%
worm_number = "w3"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250705\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250705\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250705\{worm_number}\synthetic_volume\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250705\{worm_number}\synthetic_volume\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 21/21 [00:00<00:00, 94.35it/s]

# %% [markdown]
# ### 0706_wen0065_1octanol_isoamyl_alcohol_EGCG_LTHe

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250706\20250706.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

bio_ID_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250706\ID_0706.xlsx"
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250706\labjack\output_volumes.xlsx"
for key in key_list:
        save_folder = fr"I:\WJH\flavor\raw_image\20250706\{key}"
        trend_args = {
            "h5_file_path": intensity_path,
            "save_folder": save_folder,
            "exp_name": f"{key}",
            "root_name": key,
            "date": "20250706_odor",
            "bi_ID_path": bio_ID_path,
            "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
            "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
            "labjack_excel_path": labjack_excel_path,
            "n_cols": 2,
            "row_height": 2.5,
            "col_width": 10,
            "xtick_num": 20,
            "alpha": 0.7,
            "ylabel": "deltaF/F_0"
        }
        draw_trend_signal(**trend_args)
        raw_args = {
            "h5_file_path": intensity_path,
            "save_folder": save_folder,
            "exp_name": f"{key}",
            "root_name": key,
            "date": "20250706_odor",
            "bi_ID_path": bio_ID_path,
            "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
            "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
            "labjack_excel_path": labjack_excel_path,
            "n_cols": 2,
            "row_height": 2.5,
            "col_width": 10,
            "xtick_num": 20,
            "alpha": 0.7
        }
        draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250706\w2\w2_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250706\w2\w2_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250706\w3\w3_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250706\w3\w3_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250706\w4\w4_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250706\w4\w4_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250706\w5\w5_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250706\w5\w5_raw_neuron_signals.png

# %%
worm_number = "w5"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250706\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250706\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250706\{worm_number}\synthetic_volume\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250706\{worm_number}\synthetic_volume\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 32/32 [00:00<00:00, 89.30it/s]
# WARNING: QWindowsWindow::setGeometry: Unable to set geometry 1086x660+2384+903 (frame: 1102x699+2376+872) on QWidgetWindow/"_QtMainWindowClassWindow" on "\\.\DISPLAY1". Resulting geometry: 867x527+2383+896 (frame: 883x566+2375+865) margins: 8, 31, 8, 8 minimum size: 385x515 MINMAXINFO maxSize=0,0 maxpos=0,0 mintrack=401,554 maxtrack=0,0)

# %% [markdown]
# ### 0712_wen0065_4odors

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250712\20250712.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

bio_ID_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250712\ID_0712.xlsx"
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250712\labjack\output_volumes.xlsx"
for key in key_list:
    save_folder = fr"I:\WJH\flavor\raw_image\20250712\{key}"
    trend_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250712_odor",
        "bi_ID_path": bio_ID_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7,
        "ylabel": "deltaF/F_0"
    }
    draw_trend_signal(**trend_args)
    raw_args = {
        "h5_file_path": intensity_path,
        "save_folder": save_folder,
        "exp_name": f"{key}",
        "root_name": key,
        "date": "20250712_odor",
        "bi_ID_path": bio_ID_path,
        "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
        "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
        "labjack_excel_path": labjack_excel_path,
        "n_cols": 2,
        "row_height": 2.5,
        "col_width": 10,
        "xtick_num": 20,
        "alpha": 0.7
    }
    draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250712\w1\w1_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250712\w1\w1_raw_neuron_signals.png

# %%
worm_number = "w1"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250712\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250712\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250712\{worm_number}\synthetic_volume\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250712\{worm_number}\synthetic_volume\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 34/34 [00:00<00:00, 85.10it/s]

# %% [markdown]
# ### 0719_wen0065_5odors

# %%
intensity_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250719\20250719.h5"
import h5py
from result_plot.draw_signal import *
with h5py.File(intensity_path, 'r') as f:
    key_list = list(f.keys())

bio_ID_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250719\ID_0719.xlsx"
labjack_excel_path = r"H:\Process_temporary\WJH\olfactory\ID\result\20250719\labjack\output_volumes_new.xlsx"
for key in key_list:
    # if key != 'w5':
        save_folder = fr"I:\WJH\flavor\raw_image\20250719\{key}"
        trend_args = {
            "h5_file_path": intensity_path,
            "save_folder": save_folder,
            "exp_name": f"{key}",
            "root_name": key,
            "date": "20250712_odor",
            "bi_ID_path": bio_ID_path,
            "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
            "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
            "labjack_excel_path": labjack_excel_path,
            "n_cols": 2,
            "row_height": 2.5,
            "col_width": 10,
            "xtick_num": 20,
            "alpha": 0.7,
            "ylabel": "deltaF/F_0"
        }
        draw_trend_signal(**trend_args)
        raw_args = {
            "h5_file_path": intensity_path,
            "save_folder": save_folder,
            "exp_name": f"{key}",
            "root_name": key,
            "date": "20250712_odor",
            "bi_ID_path": bio_ID_path,
            "odor_config_file": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_info.json",
            "stimulus_color_path": r"H:\Process_temporary\WJH\sensory_pipeline_python\data_load\config\compound_color_scheme.json",
            "labjack_excel_path": labjack_excel_path,
            "n_cols": 2,
            "row_height": 2.5,
            "col_width": 10,
            "xtick_num": 20,
            "alpha": 0.7
        }
        draw_raw_signal(**raw_args)
# Out:
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250719\w1\w1_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250719\w1\w1_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250719\w2\w2_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250719\w2\w2_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250719\w3\w3_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250719\w3\w3_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250719\w4\w4_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250719\w4\w4_raw_neuron_signals.png
# dfof signal plot saved to I:\WJH\flavor\raw_image\20250719\w5\w5_dfof_neuron_signals.png
# Raw signal plot saved to I:\WJH\flavor\raw_image\20250719\w5\w5_raw_neuron_signals.png

# %%
worm_number = "w5"
green_file_path =rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250719\{worm_number}\green.npy"
red_file_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250719\{worm_number}\red.npy"
aligned_volume_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250719\{worm_number}\synthetic_volume\aligned_volumes_mip.npy"
neuron_pt_tuple_path = rf"H:\Process_temporary\WJH\olfactory\ID\image_data\20250719\{worm_number}\synthetic_volume\all_neuron_pt_tuple.npy"

viewer = id_identify_in_napari(green_file_path=green_file_path,
                        red_file_path=red_file_path,
                        neuron_pt_tuple_path=neuron_pt_tuple_path,
                        aligned_volume_path=aligned_volume_path,
                        mask_name=worm_number,
                        green_scale=[1,5,1,-1],
                        green_translate=[0,0,0,1024],
                        red_scale=[1, 5, 1, 1],
                        mask_scale=[1, 5, 1, -1],
                        mask_translate=[0,0,0,1024],)
# Out:
# Processing neuron boxes: 100%|██████████| 38/38 [00:00<00:00, 89.16it/s]
